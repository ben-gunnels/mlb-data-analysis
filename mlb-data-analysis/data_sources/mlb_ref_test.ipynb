# %%
import sys
sys.path.append("..")

from data_sources import Batter
pybaseball_batter = Batter()
# Out:
# 2025-11-09 11:21:57,185 -    DEBUG - matplotlib(1032) - matplotlib data path: c:\Users\bengu\.virtualenvs\cfeproj-oIABPDjj\lib\site-packages\matplotlib\mpl-data
# 2025-11-09 11:21:57,197 -    DEBUG - matplotlib(1032) - CONFIGDIR=C:\Users\bengu\.matplotlib
# 2025-11-09 11:21:57,259 -    DEBUG - matplotlib(1032) - interactive is False
# 2025-11-09 11:21:57,261 -    DEBUG - matplotlib(1032) - platform is win32
# 2025-11-09 11:21:57,319 -    DEBUG - matplotlib(1032) - CACHEDIR=C:\Users\bengu\.matplotlib
# 2025-11-09 11:21:57,328 -    DEBUG - matplotlib.font_manager(1032) - Using fontManager instance from C:\Users\bengu\.matplotlib\fontlist-v390.json

# %%
bref = pybaseball_batter.statcast_batting("2025-04-01")
bref
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bref = pybaseball_batter.statcast_batting("2025-04-01")
#       2 bref
#
# File c:\Users\bengu\Documents\mlb-data-analysis\mlb-data-analysis\data_sources\..\data_sources\_pybaseball\batter_stats.py:66, in Batter.statcast_batting(self, start_date, end_date, player_id)
#      60 def statcast_batting(
#      61     self,
#      62     start_date: str | Date,
#      63     end_date: str | Date | None = None,
#      64     player_id: int | None = None
#      65 ) -> pd.DataFrame:
# ---> 66     response_object = pybaseball.statcast_batter(
#      67         start_date,
#      68         end_dt=end_date,
#      69         player_id=player_id
#      70     )
#      71     return pd.DataFrame(response_object)
#
# ...
