# %%
import sys, os
import pandas as pd
sys.path.append(os.path.abspath(".."))  # go up one directory from notebooks/

import mlb_stats_api_wrapper as mod
api = mod.MLBStatsAPI()

# %%
#776759
api.standings("103", "alw")
# Out:
# 2025-11-07 22:02:25,031 -    DEBUG - statsapi(2208) - URL: https://statsapi.mlb.com/api/{ver}/standings
# 2025-11-07 22:02:25,033 -    DEBUG - statsapi(2208) - Found query param: leagueId
# 2025-11-07 22:02:25,036 -    DEBUG - statsapi(2208) - Found query param: season
# 2025-11-07 22:02:25,037 -    DEBUG - statsapi(2208) - Found query param: standingsTypes
# 2025-11-07 22:02:25,039 -    DEBUG - statsapi(2208) - Found query param: hydrate
# 2025-11-07 22:02:25,041 -    DEBUG - statsapi(2208) - Found query param: fields
# 2025-11-07 22:02:25,043 -    DEBUG - statsapi(2208) - path_params: {}
# 2025-11-07 22:02:25,043 -    DEBUG - statsapi(2208) - query_params: {'leagueId': '103', 'season': '2025', 'standingsTypes': 'regularSeason', 'hydrate': 'team(division)', 'fields': 'records,standingsType,teamRecords,team,name,division,id,nameShort,abbreviation,divisionRank,gamesBack,wildCardRank,wildCardGamesBack,wildCardEliminationNumber,divisionGamesBack,clinched,eliminationNumber,winningPercentage,type,wins,losses,leagueRank,sportRank'}
# 2025-11-07 22:02:25,046 -    DEBUG - statsapi(2208) - Replacing {ver} with default: v1.
# 2025-11-07 22:02:25,049 -    DEBUG - statsapi(2208) - URL: https://statsapi.mlb.com/api/v1/standings
# 2025-11-07 22:02:25,050 -    DEBUG - statsapi(2208) - Adding query parameter leagueId=103
# 2025-11-07 22:02:25,052 -    DEBUG - statsapi(2208) - URL: https://statsapi.mlb.com/api/v1/standings?leagueId=103
# 2025-11-07 22:02:25,053 -    DEBUG - statsapi(2208) - Adding query parameter season=2025
# 2025-11-07 22:02:25,054 -    DEBUG - statsapi(2208) - URL: https://statsapi.mlb.com/api/v1/standings?leagueId=103&season=2025
# 2025-11-07 22:02:25,055 -    DEBUG - statsapi(2208) - Adding query parameter standingsTypes=regularSeason
# 2025-11-07 22:02:25,057 -    DEBUG - statsapi(2208) - URL: https://statsapi.mlb.com/api/v1/standings?leagueId=103&season=2025&standingsTypes=regularSeason
# 2025-11-07 22:02:25,058 -    DEBUG - statsapi(2208) - Adding query parameter hydrate=team(division)
# 2025-11-07 22:02:25,061 -    DEBUG - statsapi(2208) - URL: https://statsapi.mlb.com/api/v1/standings?leagueId=103&season=2025&standingsTypes=regularSeason&hydrate=team(division)
# 2025-11-07 22:02:25,064 -    DEBUG - statsapi(2208) - Adding query parameter fields=records,standingsType,teamRecords,team,name,division,id,nameShort,abbreviation,divisionRank,gamesBack,wildCardRank,wildCardGamesBack,wildCardEliminationNumber,divisionGamesBack,clinched,eliminationNumber,winningPercentage,type,wins,losses,leagueRank,sportRank
# 2025-11-07 22:02:25,065 -    DEBUG - statsapi(2208) - URL: https://statsapi.mlb.com/api/v1/standings?leagueId=103&season=2025&standingsTypes=regularSeason&hydrate=team(division)&fields=records,standingsType,teamRecords,team,name,division,id,nameShort,abbreviation,divisionRank,gamesBack,wildCardRank,wildCardGamesBack,wildCardEliminationNumber,divisionGamesBack,clinched,eliminationNumber,winningPercentage,type,wins,losses,leagueRank,sportRank
# 2025-11-07 22:02:25,077 -    DEBUG - urllib3.connectionpool(2208) - Starting new HTTPS connection (1): statsapi.mlb.com:443
# 2025-11-07 22:02:25,978 -    DEBUG - urllib3.connectionpool(2208) - https://statsapi.mlb.com:443 "GET /api/v1/standings?leagueId=103&season=2025&standingsTypes=regularSeason&hydrate=team(division)&fields=records,standingsType,teamRecords,team,name,division,id,nameShort,abbreviation,divisionRank,gamesBack,wildCardRank,wildCardGamesBack,wildCardEliminationNumber,divisionGamesBack,clinched,eliminationNumber,winningPercentage,type,wins,losses,leagueRank,sportRank HTTP/1.1" 200 2970
# {}

# %%
pd.DataFrame([season])
# Out:
#   seasonId  hasWildcard preSeasonStartDate preSeasonEndDate seasonStartDate  \
# 0     2026         True         2026-01-01       2026-02-19      2026-02-20
#
#   springStartDate springEndDate regularSeasonStartDate lastDate1stHalf  \
# 0      2026-02-20    2026-03-24             2026-03-25      2026-07-14
#
#   allStarDate  ... regularSeasonEndDate postSeasonStartDate postSeasonEndDate  \
# 0  2026-07-14  ...           2026-09-27          2026-09-28        2026-10-31
#
#   seasonEndDate offseasonStartDate offSeasonEndDate seasonLevelGamedayType  \
# 0    2026-10-31         2026-11-01       2026-12-31                      P
#
#   gameLevelGamedayType qualifierPlateAppearances  qualifierOutsPitched
# 0                    P                       3.1                   3.0
#
# [1 rows x 21 columns]
